# %%
from functools  import partial
import numpy as np

# %%
def e(t, v, i, a, L, d, h, t0 = -10):
    return (
        1/16*((2*L*i - 2*t*v - d + 2*h)*np.abs(-2*L*i + 2*t*v + d - 2*h) - 
          (2*L*i - 2*t*v - d)*np.abs(-2*L*i + 2*t*v + d) - 
          (2*L*i - 2*t*v + d + 2*h)*np.abs(-2*L*i + 2*t*v - d - 2*h) + 
          (2*L*i - 2*t*v + d)*np.abs(-2*L*i + 2*t*v - d) - 
          (2*L*i - 2*t0*v - d + 2*h)*np.abs(-2*L*i + 2*t0*v + d - 2*h) + 
          (2*L*i - 2*t0*v - d)*np.abs(-2*L*i + 2*t0*v + d) + 
          (2*L*i - 2*t0*v + d + 2*h)*np.abs(-2*L*i + 2*t0*v - d - 2*h) - 
          (2*L*i - 2*t0*v + d)*np.abs(-2*L*i + 2*t0*v - d))*a/h
    )

def t1(v, i, L, d):
    return (L*i+d/2)/v
def t2(v, i, L, d):
    t1_ = t1(v, i, L, d)
    return t1_ + h/v
def t3(v, i, L, d):
    t2_ = t2(v, i, L, d)
    return t2_ + (d-h)/v
def t4(v, i, L, d):
    t3_ = t3(v, i, L, d)
    return t3_ + h/v

# %%
def simulate_events(
    N = 100,
    threshold = 0.5,
    offset = 5,
    a=10, 
    L=0.1, 
    h=0.08, 
    d=0.2, 
    v=0.4, 
    t0=0,
    t1=100,
    t_step = 0.1,
    noise_std = 0,
):

    current_em = np.zeros(N)
    total_em = np.zeros(N)
    events = np.zeros(N)
    eNs = []

    values = dict(a=a, L=L, h=h, d=d, v=v)
    e0 = partial(e, **values)

    t1 = L*N/v

    for time in np.arange(t0,t1,t_step):
        pixel = np.arange(N)
        total_em[pixel] = e0(t=time, i = pixel+1)
        eN = total_em[pixel] - current_em[pixel]
        event_mask = (eN > threshold)
        current_em[event_mask] = total_em[event_mask]
        events[event_mask] += 1
        
    return events, t1-t0

# %%
params = dict(
    N = 100,
    threshold = 0.5,
    offset = 5,
    a=10, 
    L=0.1, 
    h=0.08, 
    d=0.2, 
    t0=0,
    t_step = 0.1,
    v = 0.4
)
params["t1"] = params["L"]*params["N"]/params["v"]

# %%
vels = np.linspace(0.01,0.4,5)
As = np.logspace(1,2,5)
out = [[simulate_events(v=v, N = 100, d = 0.1, a = a) for v in vels] for a in As]
events = np.array([[ov[0] for ov in oa] for oa in out])
dts = np.array([[ov[1] for ov in oa] for oa in out])
total_events = np.sum(events, axis = 2)
total_event_rate = total_events/dts

# %%
total_event_rate
# Out:
# array([[ 0.144  ,  1.06425,  2.0705 ,  2.99475,  4.6    ],
#        [ 0.297  ,  3.19275,  4.4895 ,  7.502  ,  9.88   ],
#        [ 0.593  ,  5.32125,  9.6965 , 10.8295 ,  9.88   ],
#        [ 0.991  ,  8.9655 , 12.3615 , 13.3705 , 13.8    ],
#        [ 1.783  , 12.58825, 14.268  , 15.21575, 17.76   ]])

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

plt.contourf(vels, As, total_event_rate, levels = 100, cmap = cm.coolwarm)
plt.yscale("log")
plt.colorbar()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
X, Y = np.meshgrid(vels, As)
Z = total_event_rate
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')
z = z_data.values
sh_0, sh_1 = z.shape
x, y = np.linspace(0, 1, sh_0), np.linspace(0, 1, sh_1)
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-c84392f411af> in <module>
#       1 import plotly.graph_objects as go
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 # Read data from a csv
#       5 z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')
#
# ~/.local/lib/python3.8/site-packages/pandas/__init__.py in <module>
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev
#      23
#      24 try:
#
# ~/.local/lib/python3.8/site-packages/pandas/compat/__init__.py in <module>
#      12 import sys
#      13
# ---> 14 from pandas._typing import F
#      15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#
# ~/.local/lib/python3.8/site-packages/pandas/_typing.py in <module>
#     118     ArrayLike,
#     119     np.random.Generator,
# --> 120     np.random.BitGenerator,
#     121     np.random.RandomState,
#     122 ]
#
# AttributeError: module 'numpy.random' has no attribute 'BitGenerator'

# %%
# !/home/EU/chpironi/miniconda3/envs/tarsir/bin/pip3 install plotly
# Out:
# Requirement already satisfied: plotly in /home/EU/chpironi/miniconda3/envs/tarsir/lib/python3.8/site-packages (5.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/EU/chpironi/miniconda3/envs/tarsir/lib/python3.8/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /home/EU/chpironi/miniconda3/envs/tarsir/lib/python3.8/site-packages (from plotly) (1.16.0)

# %%
# !/usr/bin/pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/EU/chpironi/.local/lib/python3.8/site-packages (1.22.3)
